# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# %%
# Perform API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Retrieve Latitude and longitude, Maximum temperature, Percent humidity, Percent cloudiness, Wind speed, and Weather description.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):
     # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | jalu
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | ukiah
# Processing Record 8 of Set 1 | omboue
# Processing Record 9 of Set 1 | puteyets
# Processing Record 10 of Set 1 | daru
# Processing Record 11 of Set 1 | sao filipe
# Processing Record 12 of Set 1 | natal
# Processing Record 13 of Set 1 | obera
# Processing Record 14 of Set 1 | saint-augustin
# Processing Record 15 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | rawson
# Processing Record 20 of Set 1 | jardim
# Processing Record 21 of Set 1 | poum
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | leiyang
# Processing Record 27 of Set 1 | aswan
# Processing Record 28 of Set 1 | mporokoso
# Processing Record 29 of Set 1 | lavrentiya
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | bichura
# Processing Record 33 of Set 1 | jiuquan
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | saint-pierre
# Processing Record 36 of Set 1 | hanmer springs
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | lafiagi
# Processing Record 39 of Set 1 | peterborough
# Processing Record 40 of Set 1 | lalomanu
# City not found. Skipping...
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | pukhrayan
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 1 | grande-riviere
# City not found. Skipping...
# Processing Record 49 of Set 1 | linxia
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | beloha
# Processing Record 4 of Set 2 | ilhabela
# Processing Record 5 of Set 2 | ikire
# Processing Record 6 of Set 2 | ugoofaaru
# Processing Record 7 of Set 2 | piacabucu
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | mehamn
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | nome
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | qandala
# Processing Record 18 of Set 2 | kahului
# Processing Record 19 of Set 2 | sechura
# Processing Record 20 of Set 2 | tazovskiy
# Processing Record 21 of Set 2 | dudinka
# Processing Record 22 of Set 2 | villa carlos paz
# Processing Record 23 of Set 2 | abu kamal
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | roald
# Processing Record 26 of Set 2 | baiyin
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | narsaq
# Processing Record 31 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | granville
# Processing Record 34 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 2 | gouyave
# Processing Record 36 of Set 2 | marsh harbour
# Processing Record 37 of Set 2 | phan thiet
# Processing Record 38 of Set 2 | portland
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | santo antonio do leverger
# Processing Record 41 of Set 2 | ambulu
# Processing Record 42 of Set 2 | killam
# Processing Record 43 of Set 2 | santa lucia
# Processing Record 44 of Set 2 | sinnamary
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | bubaque
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 2 | vila velha
# Processing Record 50 of Set 2 | oussouye
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | vilyuysk
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 3 | energetik
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | krasnoarmeysk
# Processing Record 10 of Set 3 | erzin
# Processing Record 11 of Set 3 | vidosi
# Processing Record 12 of Set 3 | madang
# Processing Record 13 of Set 3 | mnogovershinnyy
# Processing Record 14 of Set 3 | benjamin aceval
# Processing Record 15 of Set 3 | hamilton
# Processing Record 16 of Set 3 | puerto berrio
# Processing Record 17 of Set 3 | kawalu
# Processing Record 18 of Set 3 | matara
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | leh
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | zalesovo
# Processing Record 25 of Set 3 | suntar
# Processing Record 26 of Set 3 | torbay
# Processing Record 27 of Set 3 | ahipara
# Processing Record 28 of Set 3 | along
# Processing Record 29 of Set 3 | amga
# Processing Record 30 of Set 3 | katsuura
# Processing Record 31 of Set 3 | bonthe
# Processing Record 32 of Set 3 | baykit
# Processing Record 33 of Set 3 | manaure
# Processing Record 34 of Set 3 | donegal
# Processing Record 35 of Set 3 | brewster
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | kununurra
# Processing Record 38 of Set 3 | namatanai
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 41 of Set 3 | leningradskiy
# Processing Record 42 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 3 | pacific grove
# Processing Record 47 of Set 3 | ulaangom
# Processing Record 48 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 4 | changping
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | gora
# Processing Record 4 of Set 4 | las vegas
# Processing Record 5 of Set 4 | cherskiy
# Processing Record 6 of Set 4 | isangel
# Processing Record 7 of Set 4 | kaka
# Processing Record 8 of Set 4 | kumluca
# Processing Record 9 of Set 4 | tuatapere
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | deputatskiy
# Processing Record 13 of Set 4 | sharya
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | huarmey
# Processing Record 16 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 4 | kirakira
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | zelenoborskiy
# Processing Record 20 of Set 4 | nkoyaphiri
# Processing Record 21 of Set 4 | conde
# Processing Record 22 of Set 4 | tumaco
# Processing Record 23 of Set 4 | alice springs
# Processing Record 24 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | hoopstad
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | butaritari
# Processing Record 29 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 4 | chuy
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | palanga
# Processing Record 34 of Set 4 | noumea
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | oranjemund
# Processing Record 38 of Set 4 | chicama
# Processing Record 39 of Set 4 | padang
# Processing Record 40 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | colares
# Processing Record 43 of Set 4 | hualmay
# Processing Record 44 of Set 4 | linjiang
# Processing Record 45 of Set 4 | batsfjord
# Processing Record 46 of Set 4 | port blair
# Processing Record 47 of Set 4 | chabahar
# Processing Record 48 of Set 4 | ostersund
# Processing Record 49 of Set 4 | bonavista
# Processing Record 50 of Set 4 | tarakan
# Processing Record 1 of Set 5 | canyon
# Processing Record 2 of Set 5 | aklavik
# Processing Record 3 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 5 | irvine
# Processing Record 5 of Set 5 | taoudenni
# Processing Record 6 of Set 5 | semey
# Processing Record 7 of Set 5 | kruisfontein
# Processing Record 8 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 5 | altamont
# Processing Record 10 of Set 5 | palmer
# Processing Record 11 of Set 5 | gao
# Processing Record 12 of Set 5 | goundam
# Processing Record 13 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 5 | orange
# Processing Record 15 of Set 5 | acarau
# Processing Record 16 of Set 5 | geraldton
# Processing Record 17 of Set 5 | kudahuvadhoo
# Processing Record 18 of Set 5 | zemio
# Processing Record 19 of Set 5 | ewa beach
# Processing Record 20 of Set 5 | berlevag
# Processing Record 21 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 5 | prokhorovka
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | caconda
# Processing Record 25 of Set 5 | peleduy
# Processing Record 26 of Set 5 | darjiling
# Processing Record 27 of Set 5 | dukat
# Processing Record 28 of Set 5 | whitehorse
# Processing Record 29 of Set 5 | ust-tsilma
# Processing Record 30 of Set 5 | margate
# Processing Record 31 of Set 5 | dicabisagan
# Processing Record 32 of Set 5 | adrar
# Processing Record 33 of Set 5 | roebourne
# Processing Record 34 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | saskylakh
# Processing Record 38 of Set 5 | paita
# Processing Record 39 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 5 | srandakan
# Processing Record 41 of Set 5 | yarada
# Processing Record 42 of Set 5 | taitung
# Processing Record 43 of Set 5 | havre-saint-pierre
# Processing Record 44 of Set 5 | vao
# Processing Record 45 of Set 5 | carutapera
# Processing Record 46 of Set 5 | tutoia
# Processing Record 47 of Set 5 | nemuro
# Processing Record 48 of Set 5 | takoradi
# Processing Record 49 of Set 5 | gorontalo
# Processing Record 50 of Set 5 | kurilsk
# Processing Record 1 of Set 6 | santiago
# Processing Record 2 of Set 6 | batagay
# Processing Record 3 of Set 6 | el banco
# Processing Record 4 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 5 of Set 6 | ribas do rio pardo
# Processing Record 6 of Set 6 | krasnovishersk
# Processing Record 7 of Set 6 | karratha
# Processing Record 8 of Set 6 | ancud
# Processing Record 9 of Set 6 | christchurch
# Processing Record 10 of Set 6 | tatawin
# Processing Record 11 of Set 6 | college
# Processing Record 12 of Set 6 | buenavista
# Processing Record 13 of Set 6 | ambilobe
# Processing Record 14 of Set 6 | lokosovo
# Processing Record 15 of Set 6 | nabire
# Processing Record 16 of Set 6 | mount barker
# Processing Record 17 of Set 6 | caravelas
# Processing Record 18 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 6 | wainwright
# Processing Record 20 of Set 6 | aleksandrov gay
# Processing Record 21 of Set 6 | morros
# Processing Record 22 of Set 6 | hilo
# Processing Record 23 of Set 6 | provideniya
# Processing Record 24 of Set 6 | port hedland
# Processing Record 25 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 6 | galle
# Processing Record 27 of Set 6 | verkhoyansk
# Processing Record 28 of Set 6 | kaitangata
# Processing Record 29 of Set 6 | lagoa
# Processing Record 30 of Set 6 | garowe
# Processing Record 31 of Set 6 | manggar
# Processing Record 32 of Set 6 | dickinson
# Processing Record 33 of Set 6 | hay river
# Processing Record 34 of Set 6 | chapais
# Processing Record 35 of Set 6 | boden
# Processing Record 36 of Set 6 | lagos
# Processing Record 37 of Set 6 | middlesex
# Processing Record 38 of Set 6 | kysyl-syr
# Processing Record 39 of Set 6 | pouebo
# Processing Record 40 of Set 6 | hammerfest
# Processing Record 41 of Set 6 | edd
# Processing Record 42 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | pangody
# Processing Record 45 of Set 6 | lebu
# Processing Record 46 of Set 6 | esik
# Processing Record 47 of Set 6 | thompson
# Processing Record 48 of Set 6 | fortuna
# Processing Record 49 of Set 6 | mar del plata
# Processing Record 50 of Set 6 | puerto colombia
# Processing Record 1 of Set 7 | boddam
# Processing Record 2 of Set 7 | mugan
# Processing Record 3 of Set 7 | great yarmouth
# Processing Record 4 of Set 7 | grao mogol
# Processing Record 5 of Set 7 | hami
# Processing Record 6 of Set 7 | asfi
# Processing Record 7 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | alta floresta
# Processing Record 9 of Set 7 | tromso
# Processing Record 10 of Set 7 | klaksvik
# Processing Record 11 of Set 7 | ous
# Processing Record 12 of Set 7 | yibin
# Processing Record 13 of Set 7 | dingle
# Processing Record 14 of Set 7 | matay
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | kavieng
# Processing Record 17 of Set 7 | termiz
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | mobile
# Processing Record 20 of Set 7 | shakhtinsk
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | ixtapa
# Processing Record 23 of Set 7 | jhalrapatan
# Processing Record 24 of Set 7 | san rafael
# Processing Record 25 of Set 7 | port hueneme
# Processing Record 26 of Set 7 | qaqortoq
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | bambous virieux
# Processing Record 29 of Set 7 | trinidad
# Processing Record 30 of Set 7 | palmas
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | hithadhoo
# Processing Record 33 of Set 7 | sampit
# Processing Record 34 of Set 7 | diffa
# Processing Record 35 of Set 7 | haines junction
# Processing Record 36 of Set 7 | kuldur
# Processing Record 37 of Set 7 | prince rupert
# Processing Record 38 of Set 7 | raga
# Processing Record 39 of Set 7 | farah
# Processing Record 40 of Set 7 | phnum penh
# City not found. Skipping...
# Processing Record 41 of Set 7 | pisco
# Processing Record 42 of Set 7 | owando
# Processing Record 43 of Set 7 | guerrero negro
# Processing Record 44 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 7 | san carlos de bariloche
# Processing Record 46 of Set 7 | bathsheba
# Processing Record 47 of Set 7 | makakilo city
# Processing Record 48 of Set 7 | acapulco
# Processing Record 49 of Set 7 | la ronge
# Processing Record 50 of Set 7 | lompoc
# Processing Record 1 of Set 8 | vitimskiy
# City not found. Skipping...
# Processing Record 2 of Set 8 | vologda
# Processing Record 3 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 8 | lorengau
# Processing Record 5 of Set 8 | almeirim
# Processing Record 6 of Set 8 | cabo san lucas
# Processing Record 7 of Set 8 | kalangala
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | dubuque
# Processing Record 10 of Set 8 | trenggalek
# Processing Record 11 of Set 8 | nagykanizsa
# Processing Record 12 of Set 8 | waitati
# Processing Record 13 of Set 8 | bideford
# Processing Record 14 of Set 8 | yangambi
# Processing Record 15 of Set 8 | marienburg
# Processing Record 16 of Set 8 | urusha
# Processing Record 17 of Set 8 | melfi
# Processing Record 18 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 8 | artyom
# Processing Record 20 of Set 8 | canada
# Processing Record 21 of Set 8 | redmond
# Processing Record 22 of Set 8 | sabang
# Processing Record 23 of Set 8 | erenhot
# Processing Record 24 of Set 8 | duz
# City not found. Skipping...
# Processing Record 25 of Set 8 | liwale
# Processing Record 26 of Set 8 | cottbus
# Processing Record 27 of Set 8 | esperantina
# Processing Record 28 of Set 8 | ambon
# Processing Record 29 of Set 8 | maniitsoq
# Processing Record 30 of Set 8 | najran
# Processing Record 31 of Set 8 | sembe
# Processing Record 32 of Set 8 | dunedin
# Processing Record 33 of Set 8 | oriximina
# Processing Record 34 of Set 8 | mount isa
# Processing Record 35 of Set 8 | ossora
# Processing Record 36 of Set 8 | road town
# Processing Record 37 of Set 8 | itoman
# Processing Record 38 of Set 8 | kamaishi
# Processing Record 39 of Set 8 | roma
# Processing Record 40 of Set 8 | egvekinot
# Processing Record 41 of Set 8 | namibe
# Processing Record 42 of Set 8 | meulaboh
# Processing Record 43 of Set 8 | mahanoro
# Processing Record 44 of Set 8 | pietersburg
# Processing Record 45 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 46 of Set 8 | chik
# Processing Record 47 of Set 8 | bafra
# Processing Record 48 of Set 8 | arenapolis
# Processing Record 49 of Set 8 | jumla
# Processing Record 50 of Set 8 | areia branca
# Processing Record 1 of Set 9 | dmytrivka
# Processing Record 2 of Set 9 | ciudad bolivar
# Processing Record 3 of Set 9 | fengzhen
# Processing Record 4 of Set 9 | riyaq
# City not found. Skipping...
# Processing Record 5 of Set 9 | ponta do sol
# Processing Record 6 of Set 9 | sao joao da barra
# Processing Record 7 of Set 9 | udachnyy
# Processing Record 8 of Set 9 | tual
# Processing Record 9 of Set 9 | maarianhamina
# Processing Record 10 of Set 9 | valleyview
# Processing Record 11 of Set 9 | nioro
# Processing Record 12 of Set 9 | tres arroyos
# Processing Record 13 of Set 9 | sola
# Processing Record 14 of Set 9 | broome
# Processing Record 15 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 17 of Set 9 | east london
# Processing Record 18 of Set 9 | mangrol
# Processing Record 19 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 20 of Set 9 | chokurdakh
# Processing Record 21 of Set 9 | laguna
# Processing Record 22 of Set 9 | severo-yeniseyskiy
# Processing Record 23 of Set 9 | talnakh
# Processing Record 24 of Set 9 | parabel
# Processing Record 25 of Set 9 | epernay
# Processing Record 26 of Set 9 | boyabat
# Processing Record 27 of Set 9 | andros town
# Processing Record 28 of Set 9 | opuwo
# Processing Record 29 of Set 9 | ozernovskiy
# Processing Record 30 of Set 9 | junin
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | culebra
# Processing Record 33 of Set 9 | leshukonskoye
# Processing Record 34 of Set 9 | sharjah
# Processing Record 35 of Set 9 | hambantota
# Processing Record 36 of Set 9 | zwickau
# Processing Record 37 of Set 9 | sjovegan
# Processing Record 38 of Set 9 | verkhnevilyuysk
# Processing Record 39 of Set 9 | moron
# Processing Record 40 of Set 9 | pangnirtung
# Processing Record 41 of Set 9 | victoria
# Processing Record 42 of Set 9 | ilulissat
# Processing Record 43 of Set 9 | verkhneuralsk
# Processing Record 44 of Set 9 | oda
# Processing Record 45 of Set 9 | balykshi
# Processing Record 46 of Set 9 | gweta
# Processing Record 47 of Set 9 | moose factory
# Processing Record 48 of Set 9 | abu dhabi
# Processing Record 49 of Set 9 | logatec
# Processing Record 50 of Set 9 | mersing
# Processing Record 1 of Set 10 | mitsamiouli
# Processing Record 2 of Set 10 | shenzhen
# Processing Record 3 of Set 10 | levikha
# Processing Record 4 of Set 10 | masterton
# Processing Record 5 of Set 10 | vestmannaeyjar
# Processing Record 6 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 7 of Set 10 | bhadrachalam
# Processing Record 8 of Set 10 | nelson bay
# Processing Record 9 of Set 10 | buraydah
# Processing Record 10 of Set 10 | vuktyl
# Processing Record 11 of Set 10 | garmsar
# Processing Record 12 of Set 10 | kosh-agach
# Processing Record 13 of Set 10 | mahina
# Processing Record 14 of Set 10 | lokhvytsya
# Processing Record 15 of Set 10 | yarmouth
# Processing Record 16 of Set 10 | chateaubelair
# Processing Record 17 of Set 10 | cascais
# Processing Record 18 of Set 10 | sharhorod
# Processing Record 19 of Set 10 | atar
# Processing Record 20 of Set 10 | envira
# Processing Record 21 of Set 10 | terra nova
# Processing Record 22 of Set 10 | lensk
# Processing Record 23 of Set 10 | vaitape
# Processing Record 24 of Set 10 | kayerkan
# Processing Record 25 of Set 10 | tautira
# Processing Record 26 of Set 10 | podosinovets
# Processing Record 27 of Set 10 | flinders
# Processing Record 28 of Set 10 | walvis bay
# Processing Record 29 of Set 10 | keti bandar
# Processing Record 30 of Set 10 | kirkland lake
# Processing Record 31 of Set 10 | newport
# Processing Record 32 of Set 10 | madruga
# Processing Record 33 of Set 10 | lashio
# Processing Record 34 of Set 10 | neiafu
# Processing Record 35 of Set 10 | bukama
# Processing Record 36 of Set 10 | thinadhoo
# Processing Record 37 of Set 10 | covington
# Processing Record 38 of Set 10 | yar-sale
# Processing Record 39 of Set 10 | zhezkazgan
# Processing Record 40 of Set 10 | igarka
# Processing Record 41 of Set 10 | southbridge
# Processing Record 42 of Set 10 | labuhan
# Processing Record 43 of Set 10 | mazyr
# Processing Record 44 of Set 10 | fairbanks
# Processing Record 45 of Set 10 | cahabon
# Processing Record 46 of Set 10 | phrai bung
# City not found. Skipping...
# Processing Record 47 of Set 10 | tura
# Processing Record 48 of Set 10 | zhangjiakou
# Processing Record 49 of Set 10 | flin flon
# Processing Record 50 of Set 10 | luanshya
# Processing Record 1 of Set 11 | bose
# Processing Record 2 of Set 11 | bria
# Processing Record 3 of Set 11 | comodoro rivadavia
# Processing Record 4 of Set 11 | waingapu
# Processing Record 5 of Set 11 | nokia
# Processing Record 6 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 7 of Set 11 | makarska
# Processing Record 8 of Set 11 | la asuncion
# Processing Record 9 of Set 11 | oistins
# Processing Record 10 of Set 11 | yabrud
# Processing Record 11 of Set 11 | vila
# Processing Record 12 of Set 11 | coahuayana
# Processing Record 13 of Set 11 | clyde river
# Processing Record 14 of Set 11 | serov
# Processing Record 15 of Set 11 | rincon
# Processing Record 16 of Set 11 | severnyy
# Processing Record 17 of Set 11 | kenai
# Processing Record 18 of Set 11 | bilibino
# Processing Record 19 of Set 11 | haverfordwest
# Processing Record 20 of Set 11 | tuyen quang
# Processing Record 21 of Set 11 | saint albans
# Processing Record 22 of Set 11 | puqi
# Processing Record 23 of Set 11 | sobolevo
# Processing Record 24 of Set 11 | asau
# Processing Record 25 of Set 11 | puksoozero
# Processing Record 26 of Set 11 | tomatlan
# Processing Record 27 of Set 11 | ust-kuyga
# Processing Record 28 of Set 11 | kikwit
# Processing Record 29 of Set 11 | merauke
# Processing Record 30 of Set 11 | shimoda
# Processing Record 31 of Set 11 | correntina
# Processing Record 32 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 33 of Set 11 | koslan
# Processing Record 34 of Set 11 | umm kaddadah
# Processing Record 35 of Set 11 | tateyama
# Processing Record 36 of Set 11 | smithers
# Processing Record 37 of Set 11 | magnor
# Processing Record 38 of Set 11 | monterey
# Processing Record 39 of Set 11 | sapele
# Processing Record 40 of Set 11 | yokadouma
# Processing Record 41 of Set 11 | safaga
# Processing Record 42 of Set 11 | mackay
# Processing Record 43 of Set 11 | urumqi
# Processing Record 44 of Set 11 | gombe
# Processing Record 45 of Set 11 | inirida
# Processing Record 46 of Set 11 | cururupu
# Processing Record 47 of Set 11 | norrtalje
# Processing Record 48 of Set 11 | nago
# Processing Record 49 of Set 11 | port lincoln
# Processing Record 50 of Set 11 | rio cuarto
# Processing Record 1 of Set 12 | batticaloa
# Processing Record 2 of Set 12 | te anau
# Processing Record 3 of Set 12 | paamiut
# Processing Record 4 of Set 12 | itupiranga
# Processing Record 5 of Set 12 | rapid valley
# Processing Record 6 of Set 12 | uglovka
# Processing Record 7 of Set 12 | puerto el triunfo
# Processing Record 8 of Set 12 | manokwari
# Processing Record 9 of Set 12 | denizli
# Processing Record 10 of Set 12 | gravdal
# Processing Record 11 of Set 12 | cayenne
# Processing Record 12 of Set 12 | aksarka
# Processing Record 13 of Set 12 | graaff-reinet
# Processing Record 14 of Set 12 | sorong
# Processing Record 15 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 12 | norman wells
# Processing Record 17 of Set 12 | jertih
# Processing Record 18 of Set 12 | wanning
# Processing Record 19 of Set 12 | ankang
# Processing Record 20 of Set 12 | georgiyevka
# Processing Record 21 of Set 12 | bom jesus
# Processing Record 22 of Set 12 | praya
# Processing Record 23 of Set 12 | skibotn
# Processing Record 24 of Set 12 | robertsport
# Processing Record 25 of Set 12 | ures
# Processing Record 26 of Set 12 | tuapse
# Processing Record 27 of Set 12 | muros
# Processing Record 28 of Set 12 | tevaitoa
# Processing Record 29 of Set 12 | ivnya
# Processing Record 30 of Set 12 | laela
# Processing Record 31 of Set 12 | middelburg
# Processing Record 32 of Set 12 | kapuskasing
# Processing Record 33 of Set 12 | tamandare
# Processing Record 34 of Set 12 | rozkishne
# Processing Record 35 of Set 12 | sterling
# Processing Record 36 of Set 12 | acucena
# Processing Record 37 of Set 12 | porto novo
# Processing Record 38 of Set 12 | sung noen
# Processing Record 39 of Set 12 | ternate
# Processing Record 40 of Set 12 | yulara
# Processing Record 41 of Set 12 | puerto escondido
# Processing Record 42 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 12 | abnub
# Processing Record 44 of Set 12 | port-cartier
# Processing Record 45 of Set 12 | fountain
# Processing Record 46 of Set 12 | kashi
# Processing Record 47 of Set 12 | grindavik
# Processing Record 48 of Set 12 | dzaoudzi
# Processing Record 49 of Set 12 | payson
# Processing Record 50 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 13 | devils lake
# Processing Record 2 of Set 13 | ushtobe
# Processing Record 3 of Set 13 | lata
# Processing Record 4 of Set 13 | nalobikha
# Processing Record 5 of Set 13 | turgoyak
# Processing Record 6 of Set 13 | faya
# Processing Record 7 of Set 13 | barranquilla
# Processing Record 8 of Set 13 | warri
# Processing Record 9 of Set 13 | saint george
# Processing Record 10 of Set 13 | nenjiang
# Processing Record 11 of Set 13 | aljezur
# Processing Record 12 of Set 13 | kuanshan
# City not found. Skipping...
# Processing Record 13 of Set 13 | port augusta
# Processing Record 14 of Set 13 | kavant
# City not found. Skipping...
# Processing Record 15 of Set 13 | broken hill
# Processing Record 16 of Set 13 | greeneville
# Processing Record 17 of Set 13 | orlik
# Processing Record 18 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 13 | traverse city
# Processing Record 20 of Set 13 | moscow
# Processing Record 21 of Set 13 | gormi
# City not found. Skipping...
# Processing Record 22 of Set 13 | cordele
# Processing Record 23 of Set 13 | fare
# Processing Record 24 of Set 13 | valdosta
# Processing Record 25 of Set 13 | maamba
# Processing Record 26 of Set 13 | talas
# Processing Record 27 of Set 13 | sebina
# Processing Record 28 of Set 13 | totness
# Processing Record 29 of Set 13 | khani
# Processing Record 30 of Set 13 | mao
# Processing Record 31 of Set 13 | pierre
# Processing Record 32 of Set 13 | boundiali
# Processing Record 33 of Set 13 | vanavara
# Processing Record 34 of Set 13 | hervey bay
# Processing Record 35 of Set 13 | ylojarvi
# Processing Record 36 of Set 13 | tabou
# Processing Record 37 of Set 13 | zakamensk
# Processing Record 38 of Set 13 | mindelo
# Processing Record 39 of Set 13 | teguldet
# Processing Record 40 of Set 13 | wajir
# Processing Record 41 of Set 13 | kushima
# Processing Record 42 of Set 13 | cidreira
# Processing Record 43 of Set 13 | mirabad
# Processing Record 44 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 13 | pelym
# Processing Record 46 of Set 13 | truth or consequences
# Processing Record 47 of Set 13 | podporozhye
# Processing Record 48 of Set 13 | vardo
# Processing Record 49 of Set 13 | skjervoy
# Processing Record 50 of Set 13 | madison
# Processing Record 1 of Set 14 | la rioja
# Processing Record 2 of Set 14 | englewood
# Processing Record 3 of Set 14 | seymchan
# Processing Record 4 of Set 14 | meadow lake
# Processing Record 5 of Set 14 | hofn
# Processing Record 6 of Set 14 | izazi
# Processing Record 7 of Set 14 | barquisimeto
# Processing Record 8 of Set 14 | surazh
# Processing Record 9 of Set 14 | bastrop
# Processing Record 10 of Set 14 | simao
# Processing Record 11 of Set 14 | hobyo
# Processing Record 12 of Set 14 | gamba
# Processing Record 13 of Set 14 | lundamo
# Processing Record 14 of Set 14 | holguin
# Processing Record 15 of Set 14 | aksu
# Processing Record 16 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 14 | okhotsk
# Processing Record 18 of Set 14 | piet retief
# Processing Record 19 of Set 14 | golden rock
# City not found. Skipping...
# Processing Record 20 of Set 14 | katangli
# Processing Record 21 of Set 14 | mount vernon
# Processing Record 22 of Set 14 | dhidhdhoo
# Processing Record 23 of Set 14 | pindiga
# Processing Record 24 of Set 14 | andenes
# Processing Record 25 of Set 14 | knysna
# Processing Record 26 of Set 14 | portobelo
# Processing Record 27 of Set 14 | pareora
# Processing Record 28 of Set 14 | basirpur
# Processing Record 29 of Set 14 | kungurtug
# Processing Record 30 of Set 14 | maykor
# Processing Record 31 of Set 14 | port macquarie
# Processing Record 32 of Set 14 | svetlogorsk
# Processing Record 33 of Set 14 | svetlyy
# Processing Record 34 of Set 14 | sioux lookout
# Processing Record 35 of Set 14 | khandyga
# Processing Record 36 of Set 14 | soe
# Processing Record 37 of Set 14 | utinga
# Processing Record 38 of Set 14 | cradock
# Processing Record 39 of Set 14 | dong hoi
# Processing Record 40 of Set 14 | goure
# Processing Record 41 of Set 14 | zastron
# Processing Record 42 of Set 14 | shache
# Processing Record 43 of Set 14 | cockburn town
# Processing Record 44 of Set 14 | olga
# Processing Record 45 of Set 14 | puerto leguizamo
# Processing Record 46 of Set 14 | malakal
# Processing Record 47 of Set 14 | coihaique
# Processing Record 48 of Set 14 | baghdad
# Processing Record 49 of Set 14 | trail
# Processing Record 50 of Set 14 | jaruco
# Processing Record 1 of Set 15 | pemangkat
# Processing Record 2 of Set 15 | pandamatenga
# Processing Record 3 of Set 15 | buala
# Processing Record 4 of Set 15 | samarai
# Processing Record 5 of Set 15 | grand forks
# Processing Record 6 of Set 15 | ituporanga
# Processing Record 7 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 15 | jacareacanga
# Processing Record 9 of Set 15 | komsomolskiy
# Processing Record 10 of Set 15 | rio gallegos
# Processing Record 11 of Set 15 | emporia
# Processing Record 12 of Set 15 | pacora
# Processing Record 13 of Set 15 | uchiza
# Processing Record 14 of Set 15 | sanlucar de barrameda
# Processing Record 15 of Set 15 | sabha
# Processing Record 16 of Set 15 | wladyslawowo
# Processing Record 17 of Set 15 | naze
# Processing Record 18 of Set 15 | pangkalanbuun
# Processing Record 19 of Set 15 | tucurui
# Processing Record 20 of Set 15 | gabu
# Processing Record 21 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 15 | nizwa
# Processing Record 23 of Set 15 | hoquiam
# Processing Record 24 of Set 15 | bilma
# Processing Record 25 of Set 15 | burica
# City not found. Skipping...
# Processing Record 26 of Set 15 | micheweni
# Processing Record 27 of Set 15 | gizo
# Processing Record 28 of Set 15 | abu samrah
# Processing Record 29 of Set 15 | yashkul
# Processing Record 30 of Set 15 | the pas
# Processing Record 31 of Set 15 | scarborough
# Processing Record 32 of Set 15 | muli
# Processing Record 33 of Set 15 | camocim
# Processing Record 34 of Set 15 | pyinmana
# Processing Record 35 of Set 15 | barillas
# Processing Record 36 of Set 15 | porbandar
# Processing Record 37 of Set 15 | lucea
# Processing Record 38 of Set 15 | mikuni
# Processing Record 39 of Set 15 | north reading
# Processing Record 40 of Set 15 | ilinskiy
# Processing Record 41 of Set 15 | norcasia
# Processing Record 42 of Set 15 | ler
# Processing Record 43 of Set 15 | masallatah
# Processing Record 44 of Set 15 | chipinge
# Processing Record 45 of Set 15 | saldanha
# Processing Record 46 of Set 15 | brae
# Processing Record 47 of Set 15 | bogovina
# Processing Record 48 of Set 15 | watsa
# Processing Record 49 of Set 15 | kizukuri
# Processing Record 50 of Set 15 | tymovskoye
# Processing Record 1 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 16 | half moon bay
# Processing Record 3 of Set 16 | bontang
# Processing Record 4 of Set 16 | zaranj
# Processing Record 5 of Set 16 | ketchikan
# Processing Record 6 of Set 16 | valmiera
# Processing Record 7 of Set 16 | taozhuang
# Processing Record 8 of Set 16 | maceio
# Processing Record 9 of Set 16 | den helder
# Processing Record 10 of Set 16 | wenling
# Processing Record 11 of Set 16 | alausi
# Processing Record 12 of Set 16 | mahajanga
# Processing Record 13 of Set 16 | mingguang
# Processing Record 14 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 16 | dzhebariki-khaya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to a new DataFrame
city_weather_df = pd.DataFrame(city_data)
# Reorder the columns
city_weather_df=city_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_weather_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cape Town      ZA -33.9258   18.4232     66.88        85          75
# 1      Mataura      NZ -46.1927  168.8643     74.48        36           5
# 2        Kapaa      US  22.0752 -159.3190     78.78        63           0
# 3         Jalu      LY  29.0331   21.5482     58.71        46          57
# 4  Port Alfred      ZA -33.5906   26.8910     65.12        81           2
#
#    Wind Speed Current Description
# 0        2.30       broken clouds
# 1        3.15           clear sky
# 2       19.57           clear sky
# 3        7.65       broken clouds
# 4        9.19           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
city_weather_df.to_csv(output_data_file, index_label="City_ID")
